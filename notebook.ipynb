# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from ingest import load_faq_data, build_index
from rag_helper import RAGBase
from openai import OpenAI
import os

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
groq_client = OpenAI(
    api_key=os.environ["GROQ_API_KEY"],
    base_url="https://api.groq.com/openai/v1",
)

# %%
assistant = RAGBase(
    index=index,
    llm_client=groq_client,
)

# %%
resultado = assistant.rag("Quem tem direito ao Pé-de-Meia?")

print(resultado['resposta'])
print(f"\nTokens — entrada: {resultado['tokens_input']} | "
      f"saída: {resultado['tokens_output']} | "
      f"total: {resultado['tokens_total']}")
# Out:
# Os estudantes que têm direito ao Pé-de-Meia são aqueles que ingressam em cursos presenciais de licenciatura e obtiveram nota mínima de 650 pontos de média simples no Enem. Isso inclui os estudantes das Áreas Básicas de Ingresso (ABIs) compostas exclusivamente por cursos de licenciatura presencial. Também há outra iniciativa chamada Pé-de-Meia EJA que atenderá estudantes do Ensino Médio da EJA entre 19 e 24 anos beneficiários do programa Bolsa Família.
#
# Tokens — entrada: 1293 | saída: 127 | total: 1420
